# %% [markdown]
# # Języki skryptowe w analizie danych - `Statsmodels`, `seaborn` i `Prophet`
# ###### dr inż. Marcin Lawnik, mgr inż. Arkadiusz Banasik

# %% [markdown]
# **Wytyczne:**
# 1. Samochody
#     + Ze strony
#
#      [https://archive.ics.uci.edu/ml/machine-learning-databases/autos/](https://archive.ics.uci.edu/ml/machine-learning-databases/autos/)
#
#         pobierz dane (plik `data` zawiera dane, plik `names` nazwy kolumn), które zestawiają dane na temat różnych modeli samochodów (można wykozrystać metodę `read_csv()` z pakietu `pandas`).
#
#     + Przygotuj dane do dalszej analizy, tzn. nazwij kolumny, pousuwaj `NaN`y, zamień w razie potrzeby typ kolumn na numeryczny (metoda `to_numeric()`), zamień wartość danych (metoda `replace()`) itp.
#     + Sprawdź czy istnieje relacja pomiędzy wybranymi zmiennymi (np. `price` z `highway-mpg`).
#     + Znajdź modele opisujące wybrane zależności.
# 1. Inflacja
#     + Ze strony
#
#     [https://pl.wikipedia.org/wiki/Ludno%C5%9B%C4%87_Polski](https://pl.wikipedia.org/wiki/Ludno%C5%9B%C4%87_Polski)
#
#     pobierz tabelę z danymi `Po II wojnie światowej`.
#     + Sprawdź, czy jest korelacja liniowa pomiędzy wybranymi kolumnami, np. `Populacja (w tys., stan na 31.12.)` z `Urodzenia żywe`. Sprawdź w taki sposób co najmniej dwie zależności.
#
# 1. `Prophet`
#  + Dla dowolnie pobranych danych przeprowadzać prognozę za pomocą biblioteki `Prophet`
#
# **Uwaga**
#
# Na Platformę Zdalnej Edukacji należy wysłać rozwiązanie co najmniej 1 zestawu. Wysyłamy pliki *ipynb* i *html*.

# %%
import pandas as pd
import numpy as np

cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data', names=cols, index_col=False)

for index, row in df.iterrows():
    for col in cols:
        if df.loc[index, col] == '?':
            df.loc[index, col] = None
            
df = df.dropna()
df

cols_to_num = ['normalized-losses', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
for col in cols_to_num:
    df[col] = pd.to_numeric(df[col])
    
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.518344   -0.520591 -0.336257
# normalized-losses   0.518344           1.000000   -0.060086  0.035541
# wheel-base         -0.520591          -0.060086    1.000000  0.871534
# length             -0.336257           0.035541    0.871534  1.000000
# width              -0.219186           0.109726    0.814991  0.838338
# height             -0.475185          -0.413702    0.555767  0.499251
# curb-weight        -0.251880           0.125858    0.810181  0.871291
# engine-size        -0.109453           0.207820    0.649206  0.725953
# bore               -0.256469          -0.031558    0.578159  0.646318
# stroke             -0.021285           0.063330    0.167449  0.121073
# compression-ratio  -0.138316          -0.127259    0.291431  0.184814
# horsepower         -0.003949           0.290511    0.516948  0.672063
# ...
